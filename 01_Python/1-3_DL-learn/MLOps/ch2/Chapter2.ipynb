# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/noahgift/regression-concepts/master/height-weight-25k.csv")

# %%
df
# Out:
#        Index  Height-Inches  Weight-Pounds
# 0          1       65.78331       112.9925
# 1          2       71.51521       136.4873
# 2          3       69.39874       153.0269
# 3          4       68.21660       142.3354
# 4          5       67.78781       144.2971
# ...      ...            ...            ...
# 24995  24996       69.50215       118.0312
# 24996  24997       64.54826       120.1932
# 24997  24998       64.69855       118.2655
# 24998  24999       67.52918       132.2682
# 24999  25000       68.87761       124.8742
#
# [25000 rows x 3 columns]

# %%
import seaborn as sns
import numpy as np

sns.lmplot(x="Height-Inches", y="Weight-Pounds", data=df)

# %%
df.describe()
# Out:
#               Index  Height-Inches  Weight-Pounds
# count  25000.000000   25000.000000   25000.000000
# mean   12500.500000      67.993114     127.079421
# std     7217.022701       1.901679      11.660898
# min        1.000000      60.278360      78.014760
# 25%     6250.750000      66.704397     119.308675
# 50%    12500.500000      67.995700     127.157750
# 75%    18750.250000      69.272958     134.892850
# max    25000.000000      75.152800     170.924000

# %%
sns.jointplot(x="Height-Inches", y="Weight-Pounds", data=df, kind="kde")

# %% [markdown]
# ## Pandas 사용해서 CSV 읽기
# 데이터 가져오기에 해당하는 부분

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/nytimes/covid-19-data/master/us-states.csv")
df.head()
# Out:
#          date       state  fips  cases  deaths
# 0  2020-01-21  Washington    53      1       0
# 1  2020-01-22  Washington    53      1       0
# 2  2020-01-23  Washington    53      1       0
# 3  2020-01-24    Illinois    17      1       0
# 4  2020-01-24  Washington    53      1       0

# %% [markdown]
# ## EDA에 해당하는 영역

# %%
import plotly.io as pio
import plotly.express as px
fig = px.scatter(top_states_march_current_df, x=top_states_march_current_df.index, y="cases", size="deaths", color="state", facet_col="state")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 3
#       1 import plotly.io as pio
#       2 import plotly.express as px
# ----> 3 fig = px.scatter(top_states_march_current_df, x=top_states_march_current_df.index, y="cases", size="deaths", color="state", facet_col="state")
#       4 fig.show()
#
# NameError: name 'top_states_march_current_df' is not defined
